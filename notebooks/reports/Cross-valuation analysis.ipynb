# %%
import os
import numpy as np
import pandas as pd

# %%
cv_simple = pd.read_csv(os.path.join('../../reports/cross_valuation', 'cross_valuation_simple.csv'))

# %%
cv_simple
# Out:
#    Unnamed: 0          model  accuracy_train    train_loss  test_loss  \
# 0           0        bagging             1.0  3.565908e-01   0.691924
# 1           1  decision_tree             1.0  9.887826e-14  10.931465
# 2           2     fconnected             1.0  6.370617e-03   0.093979
# 3           3         gboost             1.0  1.046303e-09   2.946854
# 4           4          logit             1.0  5.043599e-04   0.067616
# 5           5  random_forest             1.0  2.407096e-01   0.821825
# 6           6            svm             1.0  8.817516e+00   4.599372
#
#    accuracy_test                                         parameters
# 0       0.929293  {'estimators': [('SVM', SVC(probability=True))...
# 1       0.683502                              {'criterion': 'gini'}
# 2       0.983165  {'hidden_layer_sizes': (100,), 'activation': '...
# 3       0.629630  {'loss': 'deviance', 'learning_rate': 0.1, 'n_...
# ...
