# %%
import os
import numpy as np
import pandas as pd

# %%
cv_fselection = pd.read_csv(os.path.join('../../reports/cross_valuation', 'cross_valuation_fselection.csv'))
cv_fselection
# Out:
#    Unnamed: 0          model  accuracy_train  accuracy_test  train_loss  \
# 0           0        bagging        1.000000       0.966330    0.601418
# 1           1  decision_tree        0.926407       0.646465    0.181737
# 2           2     fconnected        1.000000       0.966330    0.001185
# 3           3          logit        1.000000       0.989899    0.000015
# 4           4  random_forest        1.000000       0.949495    0.248156
# 5           5            svm        0.994228       0.983165    2.266901
#
#    test_loss                                      gs_parameters   gs_score
# 0   0.717203                             {'weights': [1, 0, 1]}  -0.802093
# 1  11.251506  {'criterion': 'gini', 'max_depth': 50, 'min_sa... -11.976233
# 2   0.084689  {'activation': 'relu', 'alpha': 0.001, 'early_...  -0.155711
# 3   0.026660  {'C': 10000.0, 'max_iter': 1500, 'penalty': 'l...  -0.071974
# 4   0.889762  {'criterion': 'entropy', 'max_depth': 16, 'min...  -1.028849
# ...

# %%
cv_pca50 = pd.read_csv(os.path.join('../../reports/cross_valuation', 'cross_valuation_pca_50.csv'))
cv_pca50
# Out:
#    Unnamed: 0          model  accuracy_train  accuracy_test  train_loss  \
# 0           0        bagging        1.000000       0.976431    0.602109
# 1           1  decision_tree        0.893218       0.693603    0.255246
# 2           2     fconnected        1.000000       0.979798    0.001563
# 3           3          logit        1.000000       0.986532    0.000291
# 4           4  random_forest        1.000000       0.966330    0.259021
# 5           5            svm        1.000000       0.986532    2.317225
#
#    test_loss                                      gs_parameters   gs_score
# 0   0.687495                             {'weights': [1, 0, 1]}  -0.750212
# 1   8.440896  {'criterion': 'entropy', 'max_depth': 100, 'mi... -12.016987
# 2   0.082107  {'activation': 'relu', 'alpha': 0.01, 'early_s...  -0.075799
# 3   0.073062  {'C': 251.18864315095823, 'max_iter': 1500, 'p...  -0.092311
# 4   0.960743  {'criterion': 'entropy', 'max_depth': 24, 'min...  -1.091051
# ...

# %%
cv_pca150 = pd.read_csv(os.path.join('../../reports/cross_valuation', 'cross_valuation_pca_50.csv'))
cv_pca150
# Out:
#    Unnamed: 0          model  accuracy_train  accuracy_test  train_loss  \
# 0           0        bagging        1.000000       0.976431    0.602109
# 1           1  decision_tree        0.893218       0.693603    0.255246
# 2           2     fconnected        1.000000       0.979798    0.001563
# 3           3          logit        1.000000       0.986532    0.000291
# 4           4  random_forest        1.000000       0.966330    0.259021
# 5           5            svm        1.000000       0.986532    2.317225
#
#    test_loss                                      gs_parameters   gs_score
# 0   0.687495                             {'weights': [1, 0, 1]}  -0.750212
# 1   8.440896  {'criterion': 'entropy', 'max_depth': 100, 'mi... -12.016987
# 2   0.082107  {'activation': 'relu', 'alpha': 0.01, 'early_s...  -0.075799
# 3   0.073062  {'C': 251.18864315095823, 'max_iter': 1500, 'p...  -0.092311
# 4   0.960743  {'criterion': 'entropy', 'max_depth': 24, 'min...  -1.091051
# ...
